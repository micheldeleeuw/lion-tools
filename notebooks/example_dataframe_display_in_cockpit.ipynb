# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
import time
import datetime

spark=lion_tools.get_or_create_spark()
lion_tools.extend_dataframe()
lion_tools.Cockpit.clear()
lion_tools.CockpitLogging.redirect()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/28 22:03:08 WARN Utils: Your hostname, MacBook-Air-van-Michel.local, resolves to a loopback address: 127.0.0.1; using 192.168.178.45 instead (on interface en0)
# 26/02/28 22:03:08 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/28 22:03:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
my_df = spark.createDataFrame([[1, "Alice]\\n in hell{}"], [2, "Bob"]], ["id", "name"])
my_df.eC(f'{datetime.datetime.now()}', lazy=False)
print('Alice bob sent to cockpit')
# lion_tools.start_cockpit(0.05)

# %%
import subprocess
if False:
    subprocess.run(['open', str(lion_tools.settings.LION_TOOLS_COCKPIT_PATH)])

# %%
df = spark.read.parquet(str(ipynbname.path().parent.parent.joinpath("datasets", "movies.parquet")))
df.eC(f'Movies {datetime.datetime.now()}', lazy=False)
print('Movies sent to cockpit')
