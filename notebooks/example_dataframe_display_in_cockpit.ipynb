# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
import time
import datetime

spark=lion_tools.get_or_create_spark()
lion_tools.extend_dataframe()
lion_tools.Cockpit.clear()
lion_tools.CockpitLogging.redirect()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/02 10:53:00 WARN Utils: Your hostname, MacBook-Air-van-Michel.local, resolves to a loopback address: 127.0.0.1; using 192.168.178.45 instead (on interface en0)
# 26/03/02 10:53:00 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/02 10:53:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/03/02 10:53:00 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Log file /var/folders/s6/sc456nwd6z34yd6y0c5qc_ym0000gn/T/lion_tools/cockpit/_lion_tools_tmp_logging_pid_93692.log created.
# [Stage 0:>                                                          (0 + 1) / 1]
# Alice bob sent to cockpit
# Movies sent to cockpit
# Log line 0
# Log line 1
# Log line 2
# Log line 3
# Log line 4
# Log line 5
# Log line 6
# Log line 7
# Log line 8
# Log line 9
# Log line 10
# Log line 11
# Log line 12
# Log line 13
# Log line 14
# Log line 15
# Log line 16
# Log line 17
# Log line 18
# Log line 19
# Log line 20
# Log line 21
# Log line 22
# Log line 23
# Log line 24
# Log line 25
# Log line 26
# Log line 27
# Log line 28
# Log line 29
# Log line 30
# Log line 31
# Log line 32
# Log line 33
# Log line 34
# Log line 35
# Log line 36
# Log line 37
# Log line 38
# Log line 39
# Log line 40
# Log line 41
# Log line 42
# Log line 43
# Log line 44
# Log line 45
# Log line 46
# Log line 47
# Log line 48
# Log line 49
# Log line 50
# Log line 51
# Log line 52
# Log line 53
# Log line 54
# Log line 55
# Log line 56
# Log line 57
# Log line 58
# Log line 59
# Log line 60
# Log line 61
# Log line 62
# Log line 63
# Log line 64
# Log line 65
# Log line 66
# Log line 67
# Log line 68
# Log line 69
# Log line 70
# Log line 71
# Log line 72
# Log line 73
# Log line 74
# Log line 75
# Log line 76
# Log line 77
# Log line 78
# Log line 79
# Log line 80
# Log line 81
# Log line 82
# Log line 83
# Log line 84
# Log line 85
# Log line 86
# Log line 87
# Log line 88
# Log line 89
# Log line 90
# Log line 91
# Log line 92
# Log line 93
# Log line 94
# Log line 95
# Log line 96
# Log line 97
# Log line 98
# Log line 99

# %%
my_df = spark.createDataFrame([[1, "Alice]\\n in hell{}"], [2, "Bob"]], ["id", "name"])
my_df.eC(f'{datetime.datetime.now()}', lazy=False, page_length=10)
print('Alice bob sent to cockpit')
# lion_tools.start_cockpit(0.05)

# %%
import subprocess
if False:
    subprocess.run(['open', str(lion_tools.settings.LION_TOOLS_COCKPIT_PATH)])

# %%
df = spark.read.parquet(str(ipynbname.path().parent.parent.joinpath("datasets", "movies.parquet")))
df.eC(f'Movies {datetime.datetime.now()}', lazy=False, page_length=10)
print('Movies sent to cockpit')

# %%
for i in range(100):
    print(f'Log line {i}')
    time.sleep(0.3)
