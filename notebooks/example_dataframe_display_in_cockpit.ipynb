# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
import time
import datetime

spark=lion_tools.get_or_create_spark()
lion_tools.extend_dataframe()
lion_tools.Cockpit.clear()
lion_tools.CockpitLogging.redirect()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/02 14:47:30 WARN Utils: Your hostname, MacBook-Air-van-Michel.local, resolves to a loopback address: 127.0.0.1; using 192.168.178.45 instead (on interface en0)
# 26/03/02 14:47:30 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/02 14:47:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/03/02 14:47:31 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Log file /var/folders/s6/sc456nwd6z34yd6y0c5qc_ym0000gn/T/lion_tools/cockpit/_lion_tools_tmp_logging_pid_6937.log created.
# [Stage 0:>                                                          (0 + 1) / 1]
# Alice bob sent to cockpit
# Movies sent to cockpit
# Traceback (most recent call last):
#   File "/Users/micheldeleeuw/Development/lion-tools/lion_tools/src/CockpitLogging.py", line 19, in monitor
#     yield
#   File "/var/folders/s6/sc456nwd6z34yd6y0c5qc_ym0000gn/T/ipykernel_6937/3414192200.py", line 3, in <module>
#     raise Exception("This is a test exception to check error handling in the cockpit.")
# Exception: This is a test exception to check error handling in the cockpit.

# %%
my_df = spark.createDataFrame([[1, "Alice]\\n in hell{}"], [2, "Bob"]], ["id", "name"])
my_df.eC(f'{datetime.datetime.now()}', lazy=False, page_length=10)
print('Alice bob sent to cockpit')
# lion_tools.start_cockpit(0.05)

# %%
import subprocess
if False:
    subprocess.run(['open', str(lion_tools.settings.LION_TOOLS_COCKPIT_PATH)])

# %%
df = spark.read.parquet(str(ipynbname.path().parent.parent.joinpath("datasets", "movies.parquet")))
df.eC(f'Movies {datetime.datetime.now()}', lazy=False, page_length=10)
print('Movies sent to cockpit')

# %%
# for i in range(2500):
#     print(f'Log line {i}')
#     time.sleep(0.3)

# %%
# print(1)
with lion_tools.CockpitLogging.monitor():
    raise Exception("This is a test exception to check error handling in the cockpit.")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # print(1)
#       2 with lion_tools.CockpitLogging.monitor():
# ----> 3     raise Exception("This is a test exception to check error handling in the cockpit.")
#
# Exception: This is a test exception to check error handling in the cockpit.
