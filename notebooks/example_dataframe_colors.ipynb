# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
spark=lion_tools.get_or_create_spark()
lion_tools.extend_dataframe()
# spark.createDataFrame([[1, "Alice]\\n in hell{}"], [2, "Bob"]], ["id", "name"]).eDisplay(
#     file_path=str(ipynbname.path().parent.parent.joinpath("output", "unknown_dataframe_view.html"))
# )

# %%
import ipynbname
movies = spark.read.parquet(str(ipynbname.path().parent.parent.joinpath("datasets", "movies.parquet")))

movies = movies.select(*[col for col in movies.columns[0:5]])

movies.eSetColors(
    # {'color_code': 'red-50-800', 'condition': '`IMDB Rating` < 6', 'style_code': 'bold'},
    # {'column': 'Director', 'color_code': 'red-50-800', 'style_code': 'bold'},
    # {'columns': ['Director', 'Distributor'], 'color_code': 'green-50-900', 'style_code': 'italic'},
    # {'columns': ['IMDB Votes'], 'color_code': 'yellow-50-900', 'style_code': 'italic'},
    {'color_code': 'green-200-950'},
    # {'color_code': 'red-50-800'}
    # {'color_code': 'red-100-800'}
    # {'color_code': 'red-200-900'}
    # {'color_code': 'red-300-950'}
    # {'color_code': 'red-400-950'}
    # {'color_code': 'red-500-50'}
    # {'color_code': 'red-600-100'}
    # {'color_code': 'red-700-50'}
).eRound(1).eD() #.drop('_color_style').eD()

# import pyspark.sql.functions as F
# movies.eSetColors(
#     {'color_code': 'traffic_light_red', 'condition': F.col('IMDB Votes') < 6},
# ).show(truncate=False)
