# %%
# %load_ext autoreload
# %autoreload 2
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
spark=lion_tools.get_or_create_spark()
df = spark.read.parquet(str(ipynbname.path().parent.parent.joinpath("datasets", "movies.parquet")))

# %%
import pygwalker as walk
import pandas as pd

# df = je resultaat uit Databricks
walker = walk.walk(df.toPandas())
