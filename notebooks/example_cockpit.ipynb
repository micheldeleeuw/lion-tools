# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
spark=lion_tools.get_or_create_spark()
from lion_tools import Cockpit
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/02 10:52:54 WARN Utils: Your hostname, MacBook-Air-van-Michel.local, resolves to a loopback address: 127.0.0.1; using 192.168.178.45 instead (on interface en0)
# 26/03/02 10:52:54 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/02 10:52:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Cockpit.clear()
lion_tools.start_cockpit(timeout=60, log_backfill=True, page_length=10, clean_start=True, log_height=300)
# Out:
# VBox(children=(HTML(value='<style>\n    /* 1. Remove padding from tab content areas */\n    .jupyter-widgets.w…

# %%
# Cockpit.get_overview()['log']
Cockpit.print_status()
# Out:
# {'cockpit_path': '/var/folders/s6/sc456nwd6z34yd6y0c5qc_ym0000gn/T/lion_tools/cockpit',
#  'files': [],
#  'html': [],
#  'json_with_html': [],
#  'log': [],
#  'new_json': [],
#  'orphan_temp_views': [],
#  'temp_views': []}
