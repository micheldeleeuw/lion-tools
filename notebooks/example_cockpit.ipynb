# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
spark=lion_tools.get_or_create_spark()
from lion_tools import Cockpit

# %%
# Cockpit.clear()
lion_tools.start_cockpit(log_backfill=True, clean_start=False, size=3) #, page_length=5, log_length=10)

# %%
# Cockpit.get_overview()['log']
# Cockpit.print_status()
