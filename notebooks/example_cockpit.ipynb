# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
spark=lion_tools.get_or_create_spark()
from lion_tools import Cockpit
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/03 14:31:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Cockpit.clear()
lion_tools.start_cockpit(timeout=60, log_backfill=True, clean_start=True, size=6) #, page_length=5, log_length=10)

# %%
# Cockpit.get_overview()['log']
# Cockpit.print_status()
# Out:
# {'cockpit_path': '/var/folders/49/v8ywl4c11cl_4hy_7my6bylw0000gp/T/lion_tools/cockpit',
#  'files': ['_lion_tools_tmp_20260303_122143_722628.html',
#            '_lion_tools_tmp_20260303_122143_722628.json',
#            '_lion_tools_tmp_20260303_122144_687215.html',
#            '_lion_tools_tmp_20260303_122144_687215.json',
#            '_lion_tools_tmp_logging_pid_69113.log'],
#  'html': ['_lion_tools_tmp_20260303_122143_722628',
#           '_lion_tools_tmp_20260303_122144_687215'],
#  'json_with_html': ['_lion_tools_tmp_20260303_122143_722628',
#                     '_lion_tools_tmp_20260303_122144_687215'],
#  'log': ['_lion_tools_tmp_logging_pid_69113.log'],
#  'new_json': [],
#  'orphan_temp_views': [],
#  'temp_views': []}
