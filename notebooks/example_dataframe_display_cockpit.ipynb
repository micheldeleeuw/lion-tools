# %%
# %run ./initialize.ipynb

# %%
import lion_tools
import ipynbname
spark=lion_tools.start_spark()
lion_tools.extend_dataframe()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/10 12:58:58 WARN Utils: Your hostname, MacBook-Air-van-Michel.local, resolves to a loopback address: 127.0.0.1; using 192.168.178.45 instead (on interface en0)
# 26/02/10 12:58:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/10 12:58:59 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/10 12:58:59 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
my_df = spark.createDataFrame([[1, "Alice]\\n in hell{}"], [2, "Bob"]], ["id", "name"])
my_df.eDc('my cool\'" dataframe')
# Out:
# Checking file: /var/folders/s6/sc456nwd6z34yd6y0c5qc_ym0000gn/T/lion_tools/cockpit
# {'async': True,
#  'display': False,
#  'html_file': '_lion_tools_tmp_20260210_125901_249490.html',
#  'id': '_lion_tools_tmp_20260210_125901_249490',
#  'n': 1001,
#  'name': 'my cool\'" dataframe',
#  'page_length': 15,
#  'passthrough': False,
#  'temp_view_name': '_lion_tools_tmp_20260210_125901_249490_view'}

# %%
from lion_tools import settings
print("LION_TOOLS_PATH:", settings.LION_TOOLS_COCKPIT_DISPLAYS_PATH)
import os
os.remove(settings.LION_TOOLS_COCKPIT_DISPLAYS_PATH)
# Out:
# LION_TOOLS_PATH: /var/folders/s6/sc456nwd6z34yd6y0c5qc_ym0000gn/T/lion_tools/cockpit/dataframe_displays.log
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[9], line 4
#       2 print("LION_TOOLS_PATH:", settings.LION_TOOLS_COCKPIT_DISPLAYS_PATH)
#       3 import os
# ----> 4 os.remove(settings.LION_TOOLS_COCKPIT_DISPLAYS_PATH)
#
# PermissionError: [Errno 1] Operation not permitted: '/var/folders/s6/sc456nwd6z34yd6y0c5qc_ym0000gn/T/lion_tools/cockpit/dataframe_displays.log'
